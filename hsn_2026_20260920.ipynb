# %%
print("hello HSN_2026")

# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\Adhisree.M\Downloads\HSN_SAC (1).xlsx")

# %%
df

# %%
df.columns

# %%
df['HSN_Description'].title

# %%
df = df['HSN_Description'].value_counts().to_frame()

# %%
pd.DataFrame(df)

# %%
df.sort_values(by = 'HSN_Description', ascending=True)

# %%
df['HSN_Description'].count.unique()

# %%
df['HSN_Description'] = df['HSN_Description'].str.replace('%other%', 'Other', regex=True)

# %%
df.loc[df['HSN_Description'] == '%other%', 'HSN_Description'] = 'Other'
